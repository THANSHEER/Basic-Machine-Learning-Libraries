# %% [markdown]
# # **Lesson 4 - What is Pandas? What tasks are performed using Pandas?**
#
# Pandas is an open-source, BSD-licensed Python library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
#
# Python with Pandas is used in a wide range of fields including academic and commercial domains including finance, economics, Statistics, analytics, etc.

# %%
import pandas as pd

import numpy as np

# %% [markdown]
# What is a Series?
#
# Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.). The axis labels are collectively called index.
#
# We did not pass any index, so by default, it assigned the indexes ranging from 0 to len(data)-1, i.e., 0 to 3.

# %%
data = np.array(['a','b','c','d'])
s = pd.Series(data)
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
data = np.array(['a','b','c','d'])
s = pd.Series(data,index=[100,101,102,103])
print(s)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %% [markdown]
# **Practice Questions**
#
# 1. Create a series by using a dictionary.

# %%
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data)
print(s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %% [markdown]
# 2. Create a series using Scalar Value

# %%
s = pd.Series('sa', index=[0, 1, 2, 3])
print(s)
# Out:
# 0    sa
# 1    sa
# 2    sa
# 3    sa
# dtype: object

# %% [markdown]
# **What is a Data Frame?**
#
# A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
#
# ![DataFrame_Img.jpg](data:image/jpeg;base64,...)

# %%
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %% [markdown]
# **Note** − Observe, the **dtype** parameter changes the type of Age column to floating point.

# %%
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'],dtype=float)
print(df)
# Out:
#      Name   Age
# 0    Alex  10.0
# 1     Bob  12.0
# 2  Clarke  13.0
# C:\Users\Contriver\AppData\Local\Temp\ipykernel_8752\3703379687.py:2: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   df = pd.DataFrame(data,columns=['Name','Age'],dtype=float)

# %% [markdown]
# **Practice Questions**
#
# 1. Create a DataFrame from Dict of ndarrays / Lists

# %%
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %% [markdown]
# 2. Create a DataFrame from List of Dicts (Dictionaries)

# %%
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data)
print(df)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %% [markdown]
# 3. Create a DataFrame from Dict of Series

# %%
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3,4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print(df)
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %% [markdown]
# # **Dataframe Operations on Columns and Rows**
#
# 1.**Column Selection**

# %%
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print(df ['one'])
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %% [markdown]
# 2. **Column Adding**

# %%
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)

# Adding a new column to an existing DataFrame object with column label by passing new series

print ("Adding a new column by passing as Series:")
df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)

print ("Adding a new column using the existing columns in DataFrame:")
df['four']=df['one']+df['three']

print(df)
# Out:
# Adding a new column by passing as Series:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# Adding a new column using the existing columns in DataFrame:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %% [markdown]
# 3. **Column Deletion**

# %%
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']),
   'three' : pd.Series([10,20,30], index=['a','b','c'])}

df = pd.DataFrame(d)
print ("Our dataframe is:")
print(df)

# using del function
print ("Deleting the first column using DEL function:")
del df['one']
#print(p)
print(df)

# using pop function
print ("Deleting another column using POP function:")
df.pop('two')
#print(p)
print(df)
# Out:
#   Cell In[7], line 11
#     p=del df['one']
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# 4. **Row Selection**
#
#  a. **Selection by label**
#
# Rows can be selected by passing row label to a loc function.
#
# The **result is a series with labels as column names of the DataFrame**. And, the Name of the series is the label with which it is retrieved.

# %%
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print(df)
print(df.loc['b'])
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
# one    2.0
# two    2.0
# Name: b, dtype: float64

# %% [markdown]
#   b. **Selection by integer location**
#
# Rows can be selected by passing integer location to an iloc function.

# %%
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print(df)
print (df.iloc[2])
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
# one    3.0
# two    3.0
# Name: c, dtype: float64

# %% [markdown]
# 6. **Row Slicing**

# %%
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print(df)
print(df[2:4])
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two
# c  3.0    3
# d  NaN    4

# %% [markdown]
# 7. **Addition of Rows**
#
# Add new rows to a DataFrame using the append function. This function will append the rows at the end.

# %%
df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])

df = df.append(df2)
print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8
# C:\Users\Contriver\AppData\Local\Temp\ipykernel_1708\3943769728.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)

# %% [markdown]
# 8. **Deletion of Rows**
#
# Use index label to delete or drop rows from a DataFrame. If label is duplicated, then multiple rows will be dropped.
#
# If you observe, in the above example, the labels are duplicate. Let us drop a label and will see how many rows will get dropped.

# %%
df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])

df = df.append(df2)
print(df)
# Drop rows with label 0
df = df.drop(0)

print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8
#    a  b
# 1  3  4
# 1  7  8
# C:\Users\Contriver\AppData\Local\Temp\ipykernel_5800\3951415726.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)

# %% [markdown]
# In the above example, two rows were dropped because those two contain the same label 0.

# %% [markdown]
# **Practice Questions**
#
# Create a DataFrame and then perform all the above discussed operations. The list of operations are mentioned below as well.
#
# * Column Selection
#
# * Column Addition
#
# * Column Deletion
#
# * Row Selection - By Label and By Integer Location
#
# * Row Slicing
#
# * Addition of Rows
#
# * Deletion of Rows

# %% [markdown]
# # **Descriptive Statistics Function in DataFrame**
#
# 1. Sum()

# %%
#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

#Create a DataFrame
df = pd.DataFrame(d)
print(df.sum())
# Out:
# Name      TomJamesRickyVinSteveSmithJackLeeDavidGasperBe...
# Age                                                     382
# Rating                                                44.92
# dtype: object

# %% [markdown]
# When **axis = 1** in **sum** function

# %%
#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

#Create a DataFrame
df = pd.DataFrame(d)
print(df.sum(1))
# Out:
# 0     29.23
# 1     29.24
# 2     28.98
# 3     25.56
# 4     33.20
# 5     33.60
# 6     26.80
# 7     37.78
# 8     42.98
# 9     34.80
# 10    55.10
# 11    49.65
# dtype: float64
# C:\Users\Contriver\AppData\Local\Temp\ipykernel_8752\3085027314.py:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df.sum(1))

# %% [markdown]
# 2. Mean()

# %%
#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

#Create a DataFrame
df = pd.DataFrame(d)
print(df.mean())
# Out:
# Age       31.833333
# Rating     3.743333
# dtype: float64

# %% [markdown]
# 3. Standard Deviation - Std()

# %%
#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

#Create a DataFrame
df = pd.DataFrame(d)
print(df.std())
# Out:
# Age       9.232682
# Rating    0.661628
# dtype: float64

# %% [markdown]
# 4. Describing and Summarizing Data
#
# Describe() function helps in describing and summarizing data.

# %%
#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

#Create a DataFrame
df = pd.DataFrame(d)
print("Result of Describe Function:")
print(df.describe())
#print("")
# Out:
# Result of Describe Function:
#              Age     Rating
# count  12.000000  12.000000
# mean   31.833333   3.743333
# std     9.232682   0.661628
# min    23.000000   2.560000
# 25%    25.000000   3.230000
# 50%    29.500000   3.790000
# 75%    35.500000   4.132500
# max    51.000000   4.800000

# %% [markdown]
# ## **Practice Questions**
#
# Create a dataframe with multiple columns and then perform the following operations over it.
#
# * Sum
#
# * Mean
#
# * Standard Deviation
#
# * Describing Data

# %% [markdown]
# # **Indexing, Selecting, and Assigning**
#
# 1. **.loc()**
#
# To access the values by using **labels**

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(8, 4),
index = ['a','b','c','d','e','f','g','h'], columns = ['A', 'B', 'C', 'D'])
print(df)
#select all rows for a specific column
print(df.loc[:,'A'])
# Out:
#           A         B         C         D
# a -1.560721  0.993503 -0.561520  0.012288
# b  1.865578  0.194190 -1.747939 -0.688034
# c -1.741463 -1.099375 -0.502488  0.135681
# d  1.788345  0.719422 -0.529025 -2.757475
# e -1.989983 -2.123268 -0.872608 -1.637204
# f -1.424105 -0.819392  0.369569  1.396993
# g -0.876139 -0.769824  1.018867  0.677475
# h  1.299340 -0.486323  0.242791  1.246373
# a   -1.560721
# b    1.865578
# c   -1.741463
# d    1.788345
# e   -1.989983
# f   -1.424105
# g   -0.876139
# h    1.299340
# Name: A, dtype: float64

# %% [markdown]
# 2. **.iloc()**
#
# To access the values by using integers

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns = ['A', 'B', 'C', 'D'])
print(df)
# select all rows for a specific column
print(df.iloc[:,3])
# Out:
#           A         B         C         D
# 0  0.062571  1.735988  0.837087 -1.192067
# 1 -0.841548  0.105768  0.928026 -1.272432
# 2  2.663638  0.184377  0.223912  0.559237
# 3  0.373887  1.195954 -0.291553  0.029370
# 4 -2.358584 -0.848171 -0.069841 -0.723953
# 5 -0.513634 -0.381146 -0.917008 -0.945410
# 6  0.042916 -0.594379  2.320032  0.119927
# 7  1.589718 -0.074122 -0.464133 -0.541976
# 0   -1.192067
# 1   -1.272432
# 2    0.559237
# 3    0.029370
# 4   -0.723953
# 5   -0.945410
# 6    0.119927
# 7   -0.541976
# Name: D, dtype: float64

# %% [markdown]
# ## **Practice Questions**
#
# Create a dataframe with **ten rows** and **six columns** using random function of numpy and then perform following operations using **loc** and **iloc** function.
#
# 1. Print first 5 rows from column 2nd to column 5th.
#
# 2. Print all the rows of last 2 columns

# %% [markdown]
# # **Reading and Writing Files**

# %% [markdown]
# 1. Reading a CSV File
#
# In this case a file with **".csv"** extension can be imported. CSV stands for **Comma-Separated Values**.

# %%
data = pd.read_csv('C:/Users/Contriver/Downloads/Contriver 2022-20230718T170355Z-001/Contriver 2022/customers.csv')
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# In this case, **sep** parameter is the separator which tells what kind of separator is used in **".csv"** file. We also mention the number of rows to be imported and skiprows will specify the rows to be left or skipped.

# %%
data = pd.read_csv("C:/Users/Contriver/Downloads/Contriver 2022-20230718T170355Z-001/Contriver 2022/train.csv", sep=',', encoding='latin-1', nrows=1000, skiprows=[2,5])
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              3         1       3
# 2              4         1       1
# 3              6         0       3
# 4              7         0       1
# ..           ...       ...     ...
# 884          887         0       2
# 885          888         1       1
# 886          889         0       3
# 887          890         1       1
# 888          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 1                          Heikkinen, Miss. Laina  female  26.0      0      0
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 3                                Moran, Mr. James    male   NaN      0      0
# 4                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %% [markdown]
# 2. Reading an Excel File
#
# Similar to **.csv** file, excel file can also be imported.

# %%
data_excel = pd.read_excel('C:/Users/Contriver/Desktop/batch 1 final.xlsx')
#data_excel

# %% [markdown]
# 3. Writing Data to a CSV File
#
# Whenever we want to save our results, we can write our data to a **".csv"** file.

# %%
data.to_csv('my_new_file.csv',index=None)

# %% [markdown]
# # **Handling Missing Data**
#
# **What is Missing Data?**
#
# Missing data is always a problem in real life scenarios. Areas like machine learning and data mining face severe issues in the accuracy of their model predictions because of poor quality of data caused by missing values.
#
# In these areas, missing value treatment is a major point of focus to make their models more accurate and valid.
#
# Let us consider an online survey for a product. Many a times, people do not share all the information related to them. Few people share their experience, but not how long they are using the product; few people share how long they are using the product, their experience but not their contact information. Thus, in some or the other way a part of data is always missing, and this is very common in real time.
#
# **Using reindexing, we have created a DataFrame with missing values. In the output, NaN means Not a Number.**

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f',
'h'],columns=['one', 'two', 'three'])
print(df)
df2 = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])

print(df2)
# Out:
#         one       two     three
# a -1.928052  1.048813 -1.058987
# c  0.371927  1.094744  1.220021
# e -1.088858 -1.535856 -0.659049
# f  0.405002  0.406756  1.297690
# h -0.457569  0.355331  0.538627
#         one       two     three
# a -1.928052  1.048813 -1.058987
# b       NaN       NaN       NaN
# c  0.371927  1.094744  1.220021
# d       NaN       NaN       NaN
# e -1.088858 -1.535856 -0.659049
# f  0.405002  0.406756  1.297690
# g       NaN       NaN       NaN
# h -0.457569  0.355331  0.538627

# %% [markdown]
# **Check for Missing Values**
#
# To make detecting missing values easier (and across different array dtypes), Pandas provides the isnull() and notnull() functions, which are also methods on Series and DataFrame objects −

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f',
'h'],columns=['one', 'two', 'three'])

df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])

print(df['one'].isnull())
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f',
'h'],columns=['one', 'two', 'three'])

df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])

print(df['one'].notnull())
# Out:
# a     True
# b    False
# c     True
# d    False
# e     True
# f     True
# g    False
# h     True
# Name: one, dtype: bool

# %% [markdown]
# **Calculations with Missing Data**
#
# * When summing data, NA will be treated as Zero
#
# * If the data are all NA, then the result will be NA

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f',
'h'],columns=['one', 'two', 'three'])

df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
print(df)
print(df['one'].sum())
# Out:
#         one       two     three
# a -0.421625  0.066150 -1.673341
# b       NaN       NaN       NaN
# c -2.312942  0.456866  0.365625
# d       NaN       NaN       NaN
# e  1.107920  1.236111 -0.917253
# f -1.317380 -1.668269  0.118674
# g       NaN       NaN       NaN
# h  1.316174 -0.301262 -0.484045
# -1.6278534620430054

# %% [markdown]
# **Cleaning / Filling Missing Data**
#
# Pandas provides various methods for cleaning the missing values. The **fillna** function can “fill in” NA values with non-null data in a couple of ways.
#
# Replace NaN with a Scalar Value
#
# The following program shows how you can replace "NaN" with "0".

# %%
df = pd.DataFrame(np.random.randn(3, 3), index=['a', 'c', 'e'],columns=['one',
'two', 'three'])

df = df.reindex(['a', 'b', 'c'])

print(df)
print("")
print ("NaN replaced with '0':")
print(df.fillna(0))
# Out:
#         one       two     three
# a  1.041029  1.397865  0.469284
# b       NaN       NaN       NaN
# c -0.579990 -1.922415 -0.348301
#
# NaN replaced with '0':
#         one       two     three
# a  1.041029  1.397865  0.469284
# b  1.000000  1.000000  1.000000
# c -0.579990 -1.922415 -0.348301

# %% [markdown]
# **Drop Missing Values**
#
# If you want to simply exclude the missing values, then use the dropna function along with the axis argument. By default, axis=0, i.e., along row, which means that if any value within a row is NA then the whole row is excluded.

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f',
'h'],columns=['one', 'two', 'three'])

df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
print(df.dropna())
# Out:
#         one       two     three
# a  1.038262 -2.371845 -0.214590
# c  0.928514 -0.667504  0.758609
# e  0.913620 -0.308242 -2.101247
# f -0.676679 -1.072566 -0.480591
# h  0.099722 -0.376900  0.435216

# %% [markdown]
# **Replace Missing (or) Generic Values**
#
# Many times, we have to replace a generic value with some specific value. We can achieve this by applying the replace method.
#
# Replacing NA with a scalar value is equivalent behavior of the fillna() function.

# %%
df = pd.DataFrame({'one':[10,20,30,40,50,2000], 'two':[1000,0,30,40,50,60]})
print(df)

print(df.replace({1000:10,2000:60}))
# Out:
#     one   two
# 0    10  1000
# 1    20     0
# 2    30    30
# 3    40    40
# 4    50    50
# 5  2000    60
#    one  two
# 0   10   10
# 1   20    0
# 2   30   30
# 3   40   40
# 4   50   50
# 5   60   60

# %% [markdown]
# ## **Practice Questions**
#
# You are given a dataframe. Perform the following operations over it.
#
# 1. Find out the number of missing values in each column
#
# 2. Replace the missing data with a value "0".
#
# 3. Drop the missing the values
#
# 4. Replace the value "3" with "3000".

# %%
df = pd.DataFrame({"A":[12, 4, 5, None, 1],
                   "B":[None, 2, 54, 3, None],
                   "C":[20, 16, None, 3, 8],
                   "D":[14, 3, None, None, 6]})

print(df)
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0

# %% [markdown]
# # **Lesson 5**
#
# # **Pandas Operations on Text**
#
# 1. **Lower**
#
# To convert the Upper Case text into Lower Case.

# %%
s = pd.Series(['Tom', 'William Rick', 'John', 'Alber@t', np.nan, '1234','SteveSmith'])

print(s.str.lower())
# Out:
# 0             tom
# 1    william rick
# 2            john
# 3         alber@t
# 4             NaN
# 5            1234
# 6      stevesmith
# dtype: object

# %% [markdown]
# 2. **Upper**
#
# To convert the Lower Case text into Upper Case.

# %%
s = pd.Series(['Tom', 'William Rick', 'John', 'Alber@t', np.nan, '1234','SteveSmith'])

print(s.str.upper())
# Out:
# 0             TOM
# 1    WILLIAM RICK
# 2            JOHN
# 3         ALBER@T
# 4             NaN
# 5            1234
# 6      STEVESMITH
# dtype: object

# %% [markdown]
# 3. **len**
#
# To determine the length of strings present in a series.

# %%
s = pd.Series(['Tom', 'William Rick', 'John', 'Alber@t', np.nan, '1234','SteveSmith'])
print(s.str.len())
# Out:
# 0     3.0
# 1    12.0
# 2     4.0
# 3     7.0
# 4     NaN
# 5     4.0
# 6    10.0
# dtype: float64

# %% [markdown]
# 4. **Contains**
#
# To check if a particular string is present in a word or a sentence.

# %%
s = pd.Series(['Tom ', ' William Rick', 'John', 'Alber@t'])

print(s.str.contains('o'))
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# 5. **replace(a,b)**
#
# This function **replaces** a letter/alphabet with another alphabet.

# %%
s = pd.Series(['Tom ', ' William Rick', 'John', 'Alber@t'])
print(s)
print ("After replacing @ with $:")
print(s.str.replace('@','$'))
# Out:
# 0             Tom
# 1     William Rick
# 2             John
# 3          Alber@t
# dtype: object
# After replacing @ with $:
# 0             Tom
# 1     William Rick
# 2             John
# 3          Alber$t
# dtype: object

# %% [markdown]
# 6. **count(pattern)**
#
# This function helps in counting a specific string or alphabet.

# %%
s = pd.Series(['Tom ', ' William Rick', 'John', 'Alber@t'])

print ("The number of 'm's in each string:")
print(s.str.count('m'))
# Out:
# The number of 'm's in each string:
# 0    1
# 1    1
# 2    0
# 3    0
# dtype: int64

# %% [markdown]
# ## **Practice Questions**
#
# 1. You are given a series. Perform the following operations over it.
#
# * Convert all the uppercase letters to lowercase.
#
# * Convert all the lowercase letter to uppercase.
#
# * Find out the length of each string in the series.
#
# * Check if the string contains letter "e" in them.
#
# * Replace "e" with "#" in all the strings present in series.

# %%
s = pd.Series(['George', 'Michael Clarke', 'Seb@st!an', np.nan, "KobeBryant", '987654','INDIA IS MY COUNTRY'])

print(s)
# Out:
# 0                 George
# 1         Michael Clarke
# 2              Seb@st!an
# 3                    NaN
# 4             KobeBryant
# 5                 987654
# 6    INDIA IS MY COUNTRY
# dtype: object

# %% [markdown]
# # **Grouping and Sorting**

# %% [markdown]
# 1. **Split Data into Groups and Viewing it**

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

print(df.groupby('Team').groups)
# Out:
# {'Devils': [2, 3], 'Kings': [4, 6, 7], 'Riders': [0, 1, 8, 11], 'Royals': [9, 10], 'kings': [5]}

# %% [markdown]
# **Group by with multiple columns**

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

print(df.groupby(['Team','Year']).groups)
# Out:
# {('Devils', 2014): [2], ('Devils', 2015): [3], ('Kings', 2014): [4], ('Kings', 2016): [6], ('Kings', 2017): [7], ('Riders', 2014): [0], ('Riders', 2015): [1], ('Riders', 2016): [8], ('Riders', 2017): [11], ('Royals', 2014): [9], ('Royals', 2015): [10], ('kings', 2015): [5]}

# %% [markdown]
# **Iterating through Groups**
#
# **With the groupby object in hand, we can iterate through the object.**

# %%
import pandas as pd
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

grouped = df.groupby('Year')
print(grouped.groups)

for name,group in grouped:
   #print(name)
   print(group)
# Out:
# {2014: [0, 2, 4, 9], 2015: [1, 3, 5, 10], 2016: [6, 8], 2017: [7, 11]}
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 10  Royals     1  2015     804
#      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %% [markdown]
# An **aggregated function** returns a single aggregated value for each group. Once the group by object is created, several aggregation operations can be performed on the grouped data.
#
# An obvious one is aggregation via the aggregate or equivalent agg method.

# %%
import numpy as np
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

grouped = df.groupby('Year')
print(grouped['Points'].agg(np.mean))
# Out:
# Year
# 2014    795.25
# 2015    769.50
# 2016    725.00
# 2017    739.00
# Name: Points, dtype: float64

# %% [markdown]
# 3. **Sorting in Pandas**
#
# This helps in sorting (arranging) the values of array.
#
# Using the **sort_index() method**, by passing the axis arguments and the order of sorting, DataFrame can be sorted. By default, **sorting is done on row labels in ascending order**.

# %%
import numpy as np
unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])
print(unsorted_df)
sorted_df=unsorted_df.sort_index()
print(sorted_df)
# Out:
#        col2      col1
# 1  1.317004  1.388458
# 4 -0.094118 -0.878659
# 6 -0.093236 -0.353135
# 2 -0.600759  0.042104
# 3  1.255597  1.199617
# 5 -0.841727  0.712325
# 9  1.533655 -2.854564
# 8  0.688285  2.505391
# 0  0.412502  0.797103
# 7  0.262897 -1.424265
#        col2      col1
# 0  0.412502  0.797103
# 1  1.317004  1.388458
# 2 -0.600759  0.042104
# 3  1.255597  1.199617
# 4 -0.094118 -0.878659
# 5 -0.841727  0.712325
# 6 -0.093236 -0.353135
# 7  0.262897 -1.424265
# 8  0.688285  2.505391
# 9  1.533655 -2.854564

# %% [markdown]
# **Order of Sorting**
#
# By passing the Boolean value to ascending parameter, the order of the sorting can be controlled.

# %%
unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])

sorted_df = unsorted_df.sort_index(ascending=False)
print(sorted_df)
# Out:
#        col2      col1
# 9 -1.348520 -2.378464
# 8 -1.478459  0.110224
# 7 -1.234693  1.777151
# 6  0.305503  0.757050
# 5  0.048915  0.557445
# 4  0.436764  0.395015
# 3  2.187676 -0.785496
# 2 -0.175361 -2.056806
# 1 -0.094040  1.616605
# 0 -0.994580  0.894680

# %% [markdown]
# **Sort the Columns**
#
# By passing the axis argument with a value 0 or 1, the sorting can be done on the column labels.
#
# **By default, axis=0, sort by row.**

# %%
unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])
#print(unsorted_df)
sorted_df=unsorted_df.sort_index(axis=1)

print(sorted_df)
# Out:
#        col2      col1
# 1 -0.241856  1.064578
# 4 -0.243590 -0.750494
# 6  0.775239 -0.037540
# 2 -0.592091  0.729755
# 3 -1.569986 -1.007593
# 5 -1.330684  1.292883
# 9  0.300814 -0.159732
# 8 -0.986022  0.997335
# 0  0.595927 -0.941097
# 7 -0.555456 -2.843751
#        col1      col2
# 1  1.064578 -0.241856
# 4 -0.750494 -0.243590
# 6 -0.037540  0.775239
# 2  0.729755 -0.592091
# 3 -1.007593 -1.569986
# 5  1.292883 -1.330684
# 9 -0.159732  0.300814
# 8  0.997335 -0.986022
# 0 -0.941097  0.595927
# 7 -2.843751 -0.555456

# %% [markdown]
# **By Value**
#
# Like index sorting, sort_values() is the method for sorting by values. It accepts a 'by' argument which will use the column name of the DataFrame with which the values are to be sorted.

# %%
unsorted_df = pd.DataFrame({'col1':[2,1,1,1],'col2':[1,3,2,4]})

sorted_df = unsorted_df.sort_values(by='col1')

print(sorted_df)
# Out:
#    col1  col2
# 1     1     3
# 2     1     2
# 3     1     4
# 0     2     1

# %% [markdown]
# **Merge Two DataFrames on a Key**

# %%
left = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame(
   {'id':[1,2,3,4,5],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5']})
print(left)
print()
print(right)
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5
#
#    id   Name subject_id
# 0   1  Billy       sub2
# 1   2  Brian       sub4
# 2   3   Bran       sub3
# 3   4  Bryce       sub6
# 4   5  Betty       sub5

# %%
left = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame({
    'id':[1,2,3,4,5],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5']})
print(pd.merge(left,right,on='id'))
# Out:
#    id  Name_x subject_id_x Name_y subject_id_y
# 0   1    Alex         sub1  Billy         sub2
# 1   2     Amy         sub2  Brian         sub4
# 2   3   Allen         sub4   Bran         sub3
# 3   4   Alice         sub6  Bryce         sub6
# 4   5  Ayoung         sub5  Betty         sub5

# %% [markdown]
# **Merge Two DataFrames on Multiple Keys**

# %%
left = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame({
	'id':[1,2,3,4,5],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5']})
print(pd.merge(left,right,on=['id','subject_id']))
# Out:
#    id  Name_x subject_id Name_y
# 0   4   Alice       sub6  Bryce
# 1   5  Ayoung       sub5  Betty

# %% [markdown]
# **Concatenation**

# %%
one = pd.DataFrame({
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5'],
   'Marks_scored':[98,90,87,69,78]},
   index=[1,2,3,4,5])

two = pd.DataFrame({
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5'],
   'Marks_scored':[89,80,79,97,88]},
   index=[1,2,3,4,5])
print(pd.concat([one,two]))
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %% [markdown]
# ## **Practice Questions**
#
# Here we have two different dataframes. Perform the following operations over these dataframes.
#
# * Perform **groupby operation** on the two dataframes and group on the basis of Qualification column.
#
# * Perform **concatenation operation** on the dataframes.
#
# * Perform **sorting operation** on one of the dataframe on **"Age"** column
#
# * Perform **merge operation** on the two dataframes on **Qualification** column.
#
# * Perform **merge operation** on the two dataframes on **Qualification and Address** column.
#
# * Perform **concatenation operation** on the two dataframes.

# %%
# Defining a dictionary containing employee data
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj', 'George','John','Vicky','Shaun'],
        'Age':[27, 24, 22, 32, 25, 36, 24, 27],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj', 'Nagpur', 'Patna', 'Kanpur', 'Kanpur'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd','Msc', 'Msc', 'Msc', 'MA']}

# Defining a dictionary containing employee data
data2 = {'Name':['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh', 'Ajay', 'Amit', 'Ashish', 'Bipin'],
        'Age':[27, 34, 29, 29, 34, 31, 27, 27],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj', 'Delhi', 'Patna', 'Nagpur', 'Nagpur'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons', 'Btech', 'Btech', 'B.A.', 'B.A.']}

# Convert the dictionary into DataFrame
self_df = pd.DataFrame(data1,index=[0, 1, 2, 3, 4, 5, 6, 7])

# Convert the dictionary into DataFrame
self_df1 = pd.DataFrame(data2, index=[8, 9, 10, 11, 12, 13, 14, 15])

print(self_df, '\n\n', self_df1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 4  George   25     Nagpur           Msc
# 5    John   36      Patna           Msc
# 6   Vicky   24     Kanpur           Msc
# 7   Shaun   27     Kanpur            MA
#
#        Name  Age    Address Qualification
# 8     Abhi   27     Nagpur         Btech
# 9   Ayushi   34     Kanpur           B.A
# 10  Dhiraj   29  Allahabad          Bcom
# 11  Hitesh   29    Kannuaj        B.hons
# 12    Ajay   34      Delhi         Btech
# 13    Amit   31      Patna         Btech
# 14  Ashish   27     Nagpur          B.A.
# 15   Bipin   27     Nagpur          B.A.

# %% [markdown]
# # **Data Visualization in Pandas**
#
# 1. **Simple Line Plot**

# %%
df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',
   periods=10), columns=list('ABCD'))
#EXAMPLE ACCURACY AND LOSS
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# 2. **Bar Plot**

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **To produce a stacked bar plot, we pass stacked=True**

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar(stacked=True)

# %% [markdown]
# For generating horizontal bar chart, we use **barh()** function

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

df.plot.barh(stacked=True)

# %% [markdown]
# 4. **Box Plot**
#
# Box Plots helps in displaying the descriptive statistics such as mean, median, range, outliers etc. of a given data.

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box()
#MININMUM ,1ST QUARTILE,MEDIAN,3RD QUARTILE,MAXIMUM

# %% [markdown]
# 6. **Scatter Plot**
#
# The Scatter Plot is helpful in showcasing the correlation between different columns of a dataset.

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
#df.plot.scatter(x='a', y='b')
df.plot.scatter(x='a', y='b',c="red")
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# 7. **Pie Chart**
#
# The Pie Chart is used for the purpose of showing the ratio of the constituting values.

# %%
df = pd.DataFrame(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], columns=['x'])
df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f08ec918d68>],
#       dtype=object)

# %% [markdown]
# ## **Practice Questions**
#
# Use **self_df** or **self_df1** dataframes to create above discussed visualizations i.e.
#
# 1. Line Plot
#
# 2. Bar Plot
#
# 3. Box Plot
#
# 4. Scatter Plot
#
# 5. Pie Chart
